# %%
import pandas as pd

# %%
# Tạo thử một bảng danh sách sản phẩm công nghệ bằng Pandas
data = {
    'Tên sản phẩm': ['iPhone 17 Pro Max', 'Realme GT7 Pro', 'Chuột Logitech G Pro'],
    'Giá tiền (VND)': [35000000, 15000000, 2500000],
    'Trạng thái': ['Còn hàng', 'Cháy hàng', 'Còn hàng']
}

# Dùng pd để biến dữ liệu trên thành một bảng tính (DataFrame) siêu đẹp
df = pd.DataFrame(data)

# Hiển thị bảng tính ra màn hình
df
df[df['Trạng thái']=='Còn hàng']
# Out:
#            Tên sản phẩm  Giá tiền (VND) Trạng thái
# 0     iPhone 17 Pro Max        35000000   Còn hàng
# 2  Chuột Logitech G Pro         2500000   Còn hàng

# %%
import pandas as pd

# 1. Tạo thử dữ liệu khách hàng ngay trong code để chạy mà không cần file Excel thật
data = {
    'Ten': ['Tanaka', 'Sato', 'Suzuki', 'Nguyen'],
    'Dia_chi': ['Tokyo', 'Osaka', 'Tokyo', 'Saitama'],
    'Doanh_thu': [600000, 300000, 450000, 700000]
}
df = pd.DataFrame(data)

# 2. Lọc khách hàng ở Tokyo VÀ doanh thu trên 50 vạn
# (Dấu & nghĩa là VÀ, hai điều kiện phải xảy ra cùng lúc)
ket_qua = df[(df['Dia_chi'] == 'Tokyo') | (df['Doanh_thu'] > 500000)]

# 3. In kết quả ra màn hình để xem
print(ket_qua)
# Out:
#       Ten  Dia_chi  Doanh_thu
# 0  Tanaka    Tokyo     600000
# 2  Suzuki    Tokyo     450000
# 3  Nguyen  Saitama     700000

# %%
try:
    # Ở đây chúng ta cố tình bắt máy tính in ra một biến chưa từng tồn tại
    print(bien_chua_tao)
except:
    # Nếu dòng trên bị lỗi, máy sẽ lập tức nhảy xuống đây để chạy dòng này
    print("Có lỗi xảy ra rồi, nhưng chương trình không bị sập đâu nhé!")
# Out:
# Có lỗi xảy ra rồi, nhưng chương trình không bị sập đâu nhé!

# %%
def doc_du_lieu_an_toan(duong_dan):
    try:
        print(daikheu9xpro)
        # Bạn thử điền lệnh đọc file bằng pandas ở đây
         
    except:
        print("lỗi rồi nhé nhưng ao vẫn chạy tiếp")
        # Bạn thử điền lệnh in thông báo lỗi ở đây
doc_du_lieu_an_toan("duong_dan_den_file.xlsx")
# Out:
# lỗi rồi nhé nhưng ao vẫn chạy tiếp
